# %% [markdown]
# # **Connect google drive to the google colab**

# %%
from google.colab import drive
drive.mount('/content/google_drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/google_drive

# %%
file_path = "google_drive/My Drive/Colab Notebooks"

# %% [markdown]
# # **Install dependencies for rendering video in Google Colab**

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1

# %%
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# %%
# !apt-get install x11-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libxxf86dga1
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   libxxf86dga1 x11-utils
# 0 upgraded, 2 newly installed, 0 to remove and 32 not upgraded.
# Need to get 209 kB of archives.
# After this operation, 711 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Fetched 209 kB in 2s (130 kB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 146829 files and directories currently installed.)
# Preparing to unpack .../libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up x11-utils (7.7+3build1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# RUN THIS IF YOU GET ERROR BASE NOT FOUND
# !pip install pyglet --upgrade
# Out:
# Collecting pyglet
#   Downloading https://files.pythonhosted.org/packages/ff/0b/6a827e16722f24f1050b349a4d8c8b08c0c280da165f55c35616177c91c5/pyglet-1.5.5-py3-none-any.whl (1.0MB)
#      |████████████████████████████████| 1.1MB 2.6MB/s
# ERROR: gym 0.17.2 has requirement pyglet<=1.5.0,>=1.4.0, but you'll have pyglet 1.5.5 which is incompatible.
# Installing collected packages: pyglet
#   Found existing installation: pyglet 1.5.0
#     Uninstalling pyglet-1.5.0:
#       Successfully uninstalled pyglet-1.5.0
# Successfully installed pyglet-1.5.5

# %%
import gym
from gym.wrappers import Monitor
import os
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only

import math
import glob
import io
import base64
from IPython.display import HTML,clear_output,Image
from IPython import display as ipythondisplay

from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %% [markdown]
# # **Environment**

# %%
class Environment(object):
    def __init__(self,name, ACTIONS):
        self.env = gym.make(name)
        self.ACTIONS = ACTIONS
    def resetEnv(self,NUM_OF_FRAMES):
        self.env.reset()
        frames = []
        reward = 0
        done = False
        for i in range(NUM_OF_FRAMES):
            obs, r, d, info = self.env.step(self.ACTIONS["NOOP"])
            reward += r
            done = done | d
            frame = preprocessFrame(obs, RESOLUTION)
            frames.append(frame)
        return frames, reward, done
    def step(self,action):
        observation, reward, done, info = self.env.step(action)
        return observation, reward, done, info
    def render(self):
        self.env.render()
        return
    def show_video(self):
        mp4list = glob.glob('video/*.mp4')
        mp4list = sorted(mp4list)
        if len(mp4list) > 0:
            mp4 = mp4list[-1]
            print(mp4)
            video = io.open(mp4, 'r+b').read()
            encoded = base64.b64encode(video)
            ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                        loop controls style="height: 400px;">
                        <source src="data:video/mp4;base64,{0}" type="video/mp4" />
                    </video>'''.format(encoded.decode('ascii'))))
        else: 
            print("Could not find video")
        return
    def wrap_env(self):
        self.env = Monitor(self.env, os.path.join(os.getcwd(),'video'), force=True)
        return

# %% [markdown]
# # **Replay Buffer**

# %%
from numpy import random
import matplotlib.pyplot as plt
import numpy as np

class ReplayBuffer(object):
    def __init__(self,BUFFER_SIZE, RESOLUTION, NUM_OF_FRAMES):
        self.BUFFER_SIZE = BUFFER_SIZE
        self.RESOLUTION = RESOLUTION
        self.NUM_OF_FRAMES = NUM_OF_FRAMES
        self.buffer = []
    def add(self,s ,a ,r ,s_next, done):
        if (len(self.buffer) == self.BUFFER_SIZE): # if the buffer is full
            self.buffer.pop(0) # remove first element
        self.buffer.append((s,a,r,s_next,done))
    def size(self):
        return len(self.buffer)
    def sample(self, batch_size):
        if (len(self.buffer) >= batch_size):
            indicies = random.choice(self.size(), size=batch_size)
            samples=[]
            for ind in indicies:
                sample = self.buffer[ind]
                samples.append((unpackState(sample[0], self.RESOLUTION, self.NUM_OF_FRAMES),
                                sample[1],
                                sample[2],
                                unpackState(sample[3], self.RESOLUTION, self.NUM_OF_FRAMES),
                                sample[4]
                                ))
        else:
            raise ValueError("Replay buffer needs more data")
        return samples

# %% [markdown]
# # **Double Deep Q network**

# %%
from keras.layers import Input, Conv2D, Activation, Flatten, Dense
from keras.optimizers import Adam, RMSprop
from keras.models import load_model, Model
from keras import backend as K
import os 
import numpy as np
import matplotlib.pyplot as plt

class DQN(object):
    def __init__(self, RESOLUTION, NUM_OF_FRAMES, NUM_OF_ACTIONS, optimizer):
        self.network = self._createNetwork(RESOLUTION, NUM_OF_FRAMES, NUM_OF_ACTIONS, OPTIMIZER)
        self.target_network = self._createNetwork(RESOLUTION, NUM_OF_FRAMES, NUM_OF_ACTIONS, OPTIMIZER)
        self.target_network.set_weights(self.network.get_weights())
    def _createNetwork(self, RESOLUTION, NUM_OF_FRAMES, NUM_OF_ACTIONS, OPTIMIZER):
        inputs = Input(shape=(RESOLUTION, RESOLUTION, NUM_OF_FRAMES))
        X = Conv2D(filters=32, kernel_size=(8,8), strides=(4,4))(inputs)
        X = Activation('relu')(X)
        X = Conv2D(filters=64, kernel_size=(4,4), strides=(2,2))(X)
        X = Activation('relu')(X)
        X = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1))(X)
        X = Activation('relu')(X)
        X = Flatten()(X) 
        X = Dense(units=512)(X)
        X = Activation('relu')(X)
        outputs = Dense(units=NUM_OF_ACTIONS)(X)
    
        model = Model(inputs=inputs, outputs=outputs)
        model.compile(optimizer=OPTIMIZER, loss=self.huber_loss)
        return model
    def huber_loss(self,a,b,in_keras=True):
        error = a - b
        quadratic_term = error*error / 2
        linear_term = abs(error) - 1/2
        use_linear_term = (abs(error) > 1.0)
        if in_keras:
            # Keras won't let us multiply floats by booleans, so we explicitly cast the booleans to floats
            use_linear_term = K.cast(use_linear_term, 'float32')
        return use_linear_term * linear_term + (1-use_linear_term) * quadratic_term
    def train_network(self, batch, BATCH_SIZE, GAMMA, NUM_OF_ACTIONS):
        s_batch, a_batch, r_batch, s_new_batch, d_batch = map(np.array, zip(*batch))
        target_batch = np.zeros((BATCH_SIZE, NUM_OF_ACTIONS))
        for j in range(BATCH_SIZE):
            target_batch[j,:] = self.network.predict(np.expand_dims(s_batch[j],axis=0), batch_size=1) # weights will be updated only for action a_batch[j]
            Q_target_next = self.target_network.predict(np.expand_dims(s_new_batch[j],axis=0), batch_size=1)
            if (d_batch[j] == True):
                target_batch[j, int(a_batch[j])] = r_batch[j]
            else: 
                target_batch[j, int(a_batch[j])] = r_batch[j] + GAMMA*np.max(Q_target_next)
        loss = self.network.train_on_batch(s_batch, target_batch)
        return loss
    def update_target_network(self):
        self.target_network.set_weights(self.network.get_weights())
        return 
    def save_network(self,file_path):
        path = os.path.join(file_path,"trained_model")
        os.makedirs(path, exist_ok=True)
        save_path = os.path.join(path,"model.h5")
        self.network.save(save_path)
        print("The network is saved to {}".format(save_path))
    def load_network(self,file_path):
        path = os.path.join(file_path,"trained_model")
        load_path = os.path.join(path,"model.h5")
        self.network = load_model(load_path,custom_objects={'huber_loss': self.huber_loss})
        self.target_network = load_model(load_path,custom_objects={'huber_loss': self.huber_loss})
        print("The network is loaded from {}".format(load_path))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # **Additional functions**

# %%
import cv2
import numpy as np
from statistics import mean
import matplotlib.pyplot as plt
import pickle
import os
import sys

def preprocessFrame(frame, RESOLUTION): 
    # convert to gray and resize
    frame = cv2.cvtColor(cv2.resize(frame, (RESOLUTION, RESOLUTION)), cv2.COLOR_BGR2GRAY)
    # make it binary
    _, frame = cv2.threshold(frame,1,255,cv2.THRESH_BINARY)
    return frame
def packState(state):
    return np.packbits(state)
def unpackState(state, RESOLUTION, NUM_OF_FRAMES):
    return np.unpackbits(state).reshape(RESOLUTION,RESOLUTION,NUM_OF_FRAMES)
def stackFrames(frames):
    return np.stack(frames, axis=-1).astype("uint8")
def average(data, frequency, start_avg_point):
    average_data = []
    if (len(data) > start_avg_point):
        round_num = -(len(str(frequency))-1)
        for i in range(0,round(len(data),round_num)-frequency,frequency):
            avg_data=mean(data[i:i+frequency])
            average_data.append(avg_data)
    return average_data
def save_to_disk(txt_path, values):
    if os.path.isfile(txt_path):
        os.remove(txt_path)
    with open(txt_path, "wb") as fp:   
        pickle.dump(values, fp)
    return
def load_from_disk(txt_path):
    with open(txt_path, "rb") as f:
        values =  pickle.load(f)
    return values
def plot_variable(values, xlabel, ylabel, title, save_path):
    fig = plt.figure(figsize=(12, 6))
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.plot(values, figure=fig)
    plt.savefig(save_path)
    plt.show(block=False)
    return
def report(losses, episode_rewards, Q_values, file_path, replay_buffer, epsilon, eval_rewards, eval_Q_values):
    plots_dir = os.path.join(file_path,'plots')
    os.makedirs(plots_dir, exist_ok=True)
    # episode rewards
    save_path = os.path.join(plots_dir,"reward.png")
    plot_variable(episode_rewards, 'episodes', 'reward', 'Reward through episodes', save_path)
    # average reward
    average_rewards = average(episode_rewards, 100,200)
    if (len(average_rewards) != 0):
        save_path = os.path.join(plots_dir,"rewardAveraged.png")
        plot_variable(average_rewards, 'episodes', 'reward', 'Reward averaged over last 100 episodes', save_path)
    # average loss
    average_losses = average(losses, 1000, 20000)
    if (len(average_losses) != 0):
        save_path = os.path.join(plots_dir,"lossAveraged.png")
        plot_variable(average_losses, 'num of weight updates*1000', 'loss', 'Loss averaged over 1000 weight updates', save_path)       
    # average Q values
    average_Q = average(Q_values, 1000, 20000)
    if (len(average_Q) != 0):
        save_path = os.path.join(plots_dir,"QvaluesAveraged.png")
        plot_variable(average_Q, 'num of weight updates*1000', 'Q value', 'Q values averaged over 1000 weight updates', save_path)
    # eval rewards
    save_path = os.path.join(plots_dir,"evalRewards.png")
    plot_variable(eval_rewards, 'epochs', 'reward', 'Reward averaged over 30 episodes', save_path)
    save_path = os.path.join(plots_dir,"evalQvalues.png")
    plot_variable(eval_Q_values, 'epochs', 'Q value', 'Q values averaged over 30 episodes', save_path)
    # save variables to file
    txt_path = os.path.join(file_path,"loss.txt")
    save_to_disk(txt_path,losses)
    print("Loss is saved to {}".format(txt_path))
    txt_path = os.path.join(file_path,"Qvalues.txt")
    save_to_disk(txt_path,Q_values)
    print("Q values are saved to {}".format(txt_path))    
    txt_path = os.path.join(file_path,"rewards.txt")
    save_to_disk(txt_path,episode_rewards)
    print("Rewards are saved to {}".format(txt_path))
    txt_path = os.path.join(file_path,"replayBuffer.txt")
    save_to_disk(txt_path,replay_buffer)
    print("Replay buffer is saved to {}".format(txt_path))
    txt_path = os.path.join(file_path,"epsilon.txt")
    save_to_disk(txt_path,epsilon)
    print("Epsilon is saved to {}".format(txt_path))
    txt_path = os.path.join(file_path,"evalRewards.txt")
    save_to_disk(txt_path,eval_rewards)
    print("Eval rewards are saved to {}".format(txt_path))
    txt_path = os.path.join(file_path,"evalQvalues.txt")
    save_to_disk(txt_path,eval_Q_values)
    print("Eval Q values are saved to {}".format(txt_path))
    return
def load_saved_data(file_path):
    # load saved variables
    txt_path = os.path.join(file_path,"epsilon.txt")
    epsilon = load_from_disk(txt_path)
    print("Epsilon is loaded from {}".format(txt_path))
    txt_path = os.path.join(file_path,"replayBuffer.txt")
    replay_buffer = load_from_disk(txt_path)
    print("Replay Buffer is loaded from {}".format(txt_path))
    txt_path = os.path.join(file_path,"loss.txt")
    losses = load_from_disk(txt_path)
    losses = list(losses)
    print("Loss is loaded from {}".format(txt_path))
    txt_path = os.path.join(file_path,"Qvalues.txt")
    Q_values = load_from_disk(txt_path)
    print("Q values are loaded from {}".format(txt_path))
    txt_path = os.path.join(file_path,"rewards.txt")
    episode_rewards = load_from_disk(txt_path)
    print("Rewards are loaded from {}".format(txt_path))
    txt_path = os.path.join(file_path,"evalRewards.txt")
    eval_rewards = load_from_disk(txt_path)
    print("Eval rewards are loaded from {}".format(txt_path))
    txt_path = os.path.join(file_path,"evalQvalues.txt")
    eval_Q_values = load_from_disk(txt_path)
    print("Eval Q values are loaded from {}".format(txt_path))
    num_of_weight_updates = len(losses)
    return epsilon, replay_buffer, losses, Q_values, episode_rewards, num_of_weight_updates, eval_rewards, eval_Q_values

# %% [markdown]
# # **Hyperparameters**

# %%
ACTIONS = {"NOOP":0,"FIRE":1,"RIGHT":2,"LEFT":3,"RIGHTFIRE":4,"LEFTFIRE":5}
NUM_OF_FRAMES = 4 # number of frames that make 1 state
EPISODES = 10000 # number of episodes
BUFFER_SIZE = 300000 # size of the replay buffer(can not put bigger size, RAM)
MIN_OBSERVATIONS = 30000
RESOLUTION = 84 # resolution of frames
BATCH_SIZE = 32
EPSILON_START = 1 # starting value for the exploration probability
EPSILON_END = 0.1 
FINAL_EXPLORATION_STATE = 500000 # final frame for which epsilon is decayed
GAMMA = 0.99 # discount factor
TARGET_NETWORK_UPDATE_FREQ = 40000 
REPORT_EPISODE_FREQ = 100
TRAINING_FREQUENCY = 4
OPTIMIZER = RMSprop(lr=0.00025,rho=0.95,epsilon=0.01)

# %% [markdown]
# # **Agent**

# %%
from statistics import mean

class Agent(object):

    def EGreedyPolicy(self,Q, state, epsilon, NUM_OF_ACTIONS):
        Q_values = Q.network.predict(np.expand_dims(state,axis=0), batch_size=1)
        if (np.random.random() < epsilon): # exploration
            action = np.random.randint(0, NUM_OF_ACTIONS)
            is_greedy_action = False
        else:  # exploitation
            action = np.argmax(Q_values)
            is_greedy_action = True
        return action, Q_values[0,action], is_greedy_action
    def decayEpsilon(self, epsilon, start, end, states_num):
        d_epsilon = (start-end)/states_num
        epsilon = epsilon - d_epsilon
        return epsilon
    def getCustomReward(self, reward, info, LIFE_CHECKPOINT):
        if reward > 0:
            reward = 1
        if 'ale.lives' in info is not None:
            if info['ale.lives'] != LIFE_CHECKPOINT: # if you lost a life
                if LIFE_CHECKPOINT == 0: # when starting a new episode
                    LIFE_CHECKPOINT = 3
                    reward = 0
                else: # get punishment
                    LIFE_CHECKPOINT = info['ale.lives']
                    reward = -1
        else:
            print("Lives is None")
            if LIFE_CHECKPOINT != 0:
                LIFE_CHECKPOINT = 0
                reward = -1
            else:
                reward = 0
        return reward, LIFE_CHECKPOINT
    def train(self, Q, space_invaders, file_path, continue_training, EPISODE=0):
        if continue_training:
            epsilon, replay_buffer, losses, Q_values, episode_rewards, num_of_weight_updates, eval_rewards, eval_Q_values = load_saved_data(file_path)
        else:
            epsilon = EPSILON_START
            num_of_weight_updates = 0
            episode_rewards = []
            losses = []
            Q_values = [] 
            eval_rewards = []
            eval_Q_values = []
            replay_buffer = ReplayBuffer(BUFFER_SIZE, RESOLUTION, NUM_OF_FRAMES)
        
        frame_count = 0
        LIFE_CHECKPOINT = 3
        for episode in range(EPISODE,EPISODES):
            # reset the environment and init variables
            frames, _, _ = space_invaders.resetEnv(NUM_OF_FRAMES)
            state = stackFrames(frames)
            done = False
            episode_reward = 0
            episode_reward_clipped = 0
            frames_buffer = frames # contains preprocessed frames (not stacked)
            while not done:
                if (episode % REPORT_EPISODE_FREQ == 0):
                    space_invaders.render()
                # select an action from behaviour policy
                action, Q_value, is_greedy_action = self.EGreedyPolicy(Q, state, epsilon, len(ACTIONS))
                # perform action in the environment
                observation, reward, done, info = space_invaders.step(action)
                episode_reward += reward # update episode reward
                reward, LIFE_CHECKPOINT = self.getCustomReward(reward, info, LIFE_CHECKPOINT)
                episode_reward_clipped += reward
                frame = preprocessFrame(observation, RESOLUTION)
                # pop first frame from the buffer, and add new at the end (s1=[f1,f2,f3,f4], s2=[f2,f3,f4,f5])
                frames_buffer.append(frame) 
                frames_buffer.pop(0)
                new_state = stackFrames(frames_buffer)
                # add (s,a,r,s') tuple to the replay buffer
                replay_buffer.add(packState(state), action, reward, packState(new_state), done)
                
                state = new_state # new state becomes current state
                frame_count += 1
                if (replay_buffer.size() > MIN_OBSERVATIONS): # if there is enough data in replay buffer
                    Q_values.append(Q_value)
                    if (frame_count % TRAINING_FREQUENCY == 0):
                        batch = replay_buffer.sample(BATCH_SIZE)
                        loss = Q.train_network(batch, BATCH_SIZE, GAMMA, len(ACTIONS))
                        losses.append(loss)
                        num_of_weight_updates += 1
                    if (epsilon > EPSILON_END):
                        epsilon = self.decayEpsilon(epsilon, EPSILON_START, EPSILON_END, FINAL_EXPLORATION_STATE)
                if (num_of_weight_updates % TARGET_NETWORK_UPDATE_FREQ == 0) and (num_of_weight_updates != 0): # update weights of target network
                    Q.update_target_network() 
                    print("Target_network is updated!")
            episode_rewards.append(episode_reward)

            print("EPISODE {}".format(episode))
            print("reward: {}".format(episode_reward))
            print("Clipped reward: {}".format(episode_reward_clipped))
            print("epsilon: {}".format(epsilon))
            print("buffer size: {}".format(replay_buffer.size()))
            if (episode % REPORT_EPISODE_FREQ == 0):
                space_invaders.show_video()
                Q.save_network(file_path)
                _, _, eval_reward, eval_Q_value = self.play_game(0.05, Q, space_invaders, 30)
                eval_rewards.append(eval_reward)
                eval_Q_values.append(eval_Q_value)
                report(losses, episode_rewards, Q_values, file_path, replay_buffer, epsilon, eval_rewards, eval_Q_values)
    def play_game(self,epsilon, Q, space_invaders, episodes, load_pretrained=False, render=False):
        print("Playing the game!")
        if load_pretrained:
            Q.load_network(file_path)
        episode_rewards = []
        Q_values = []
        for episode in range(episodes):
            frames, reward, _ = space_invaders.resetEnv(NUM_OF_FRAMES)
            state = stackFrames(frames)
            done = False
            episode_reward = 0
            frames_buffer = frames
            while not done:
                # select an action from behaviour policy
                action, Q_value, is_greedy_action = self.EGreedyPolicy(Q, state, epsilon, len(ACTIONS))
                if render:
                    space_invaders.render()
                # perform action in the environment
                observation, reward, done, info = space_invaders.step(action)
                # pop first frame from the buffer, and add new at the end (s1=[f1,f2,f3,f4], s2=[f2,f3,f4,f5])
                frame = preprocessFrame(observation, RESOLUTION)
                frames_buffer.append(frame) 
                frames_buffer.pop(0)
                new_state = stackFrames(frames_buffer)
                state = new_state # new state becomes current state

                episode_reward += reward # update episode reward
                Q_values.append(Q_value)
            print("EPSIODE {}".format(episode))
            print("episode reward: {}".format(episode_reward))
            episode_rewards.append(episode_reward)
        return episode_rewards, Q_values, mean(episode_rewards), mean(Q_values)

# %% [markdown]
# # **Start training**

# %%
import gym
import numpy as np
import sys
# %matplotlib inline
import matplotlib.pyplot as plt

space_invaders = Environment('SpaceInvaders-v0',ACTIONS)
space_invaders.wrap_env()
Q = DQN(RESOLUTION, NUM_OF_FRAMES, len(ACTIONS), OPTIMIZER)

agent = Agent()
agent.train(Q, space_invaders, file_path, continue_training=False)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # **Continue training**

# %%
import gym
import numpy as np
import sys

space_invaders = Environment('SpaceInvaders-v0',ACTIONS)
space_invaders.wrap_env()
Q = DQN(RESOLUTION, NUM_OF_FRAMES, len(ACTIONS), OPTIMIZER)
Q.load_network(file_path)

agent = Agent()
agent.train(Q, space_invaders, file_path, continue_training=True, EPISODE=500)
# Out:
# The network is loaded from google_drive/My Drive/Colab Notebooks/trained_model/model.h5
# Epsilon is loaded from google_drive/My Drive/Colab Notebooks/epsilon.txt
# Replay Buffer is loaded from google_drive/My Drive/Colab Notebooks/replayBuffer.txt
# Loss is loaded from google_drive/My Drive/Colab Notebooks/loss.txt
# Q values are loaded from google_drive/My Drive/Colab Notebooks/Qvalues.txt
# Rewards are loaded from google_drive/My Drive/Colab Notebooks/rewards.txt
# Eval rewards are loaded from google_drive/My Drive/Colab Notebooks/evalRewards.txt
# Eval Q values are loaded from google_drive/My Drive/Colab Notebooks/evalQvalues.txt
# EPISODE 500
# reward: 45.0
# Clipped reward: 2.0
# epsilon: 0.4130037999858035
# buffer size: 300000
# video/openaigym.video.0.118.video000000.mp4
# <video alt="test" autoplay
#                         loop controls style="height: 400px;">
#                         <source src="..." type="video/mp4" />
#                     </video>
# The network is saved to google_drive/My Drive/Colab Notebooks/trained_model/model.h5
# Playing the game!
# EPSIODE 0
# episode reward: 55.0
# EPSIODE 1
# episode reward: 515.0
# EPSIODE 2
# episode reward: 30.0
# EPSIODE 3
# episode reward: 225.0
# EPSIODE 4
# episode reward: 55.0
# EPSIODE 5
# episode reward: 670.0
# EPSIODE 6
# episode reward: 130.0
# EPSIODE 7
# episode reward: 390.0
# EPSIODE 8
# episode reward: 520.0
# EPSIODE 9
# episode reward: 85.0
# EPSIODE 10
# episode reward: 145.0
# EPSIODE 11
# episode reward: 180.0
# EPSIODE 12
# episode reward: 35.0
# EPSIODE 13
# episode reward: 110.0
# EPSIODE 14
# episode reward: 60.0
# EPSIODE 15
# episode reward: 120.0
# EPSIODE 16
# episode reward: 80.0
# EPSIODE 17
# episode reward: 35.0
# EPSIODE 18
# episode reward: 125.0
# EPSIODE 19
# episode reward: 390.0
# EPSIODE 20
# episode reward: 335.0
# EPSIODE 21
# episode reward: 155.0
# EPSIODE 22
# episode reward: 180.0
# EPSIODE 23
# episode reward: 190.0
# EPSIODE 24
# episode reward: 170.0
# EPSIODE 25
# episode reward: 230.0
# EPSIODE 26
# episode reward: 215.0
# EPSIODE 27
# episode reward: 10.0
# EPSIODE 28
# episode reward: 105.0
# EPSIODE 29
# episode reward: 70.0
# Loss is saved to google_drive/My Drive/Colab Notebooks/loss.txt
# Q values are saved to google_drive/My Drive/Colab Notebooks/Qvalues.txt
# Rewards are saved to google_drive/My Drive/Colab Notebooks/rewards.txt
# Replay buffer is saved to google_drive/My Drive/Colab Notebooks/replayBuffer.txt
# Epsilon is saved to google_drive/My Drive/Colab Notebooks/epsilon.txt
# Eval rewards are saved to google_drive/My Drive/Colab Notebooks/evalRewards.txt
# Eval Q values are saved to google_drive/My Drive/Colab Notebooks/evalQvalues.txt
# EPISODE 501
# reward: 5.0
# Clipped reward: -2.0
# epsilon: 0.412287399985805
# buffer size: 300000
# EPISODE 502
# reward: 50.0
# Clipped reward: 3.0
# epsilon: 0.4116213999858064
# buffer size: 300000
# EPISODE 503
# reward: 50.0
# Clipped reward: 1.0
# epsilon: 0.4109805999858077
# buffer size: 300000
# EPISODE 504
# reward: 35.0
# Clipped reward: 1.0
# epsilon: 0.4102785999858092
# buffer size: 300000
# EPISODE 505
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.4090815999858117
# buffer size: 300000
# EPISODE 506
# reward: 320.0
# Clipped reward: 6.0
# epsilon: 0.407495799985815
# buffer size: 300000
# EPISODE 507
# reward: 280.0
# Clipped reward: 15.0
# epsilon: 0.4056651999858188
# buffer size: 300000
# EPISODE 508
# reward: 10.0
# Clipped reward: -1.0
# epsilon: 0.4050279999858201
# buffer size: 300000
# EPISODE 509
# reward: 430.0
# Clipped reward: 13.0
# epsilon: 0.4035465999858232
# buffer size: 300000
# EPISODE 510
# reward: 150.0
# Clipped reward: 6.0
# epsilon: 0.40233159998582574
# buffer size: 300000
# EPISODE 511
# reward: 140.0
# Clipped reward: 5.0
# epsilon: 0.40117239998582815
# buffer size: 300000
# EPISODE 512
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.3999933999858306
# buffer size: 300000
# EPISODE 513
# reward: 165.0
# Clipped reward: 7.0
# epsilon: 0.3984687999858338
# buffer size: 300000
# EPISODE 514
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.3972519999858363
# buffer size: 300000
# EPISODE 515
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.3958209999858393
# buffer size: 300000
# EPISODE 516
# reward: 110.0
# Clipped reward: 6.0
# epsilon: 0.39458979998584187
# buffer size: 300000
# EPISODE 517
# reward: 215.0
# Clipped reward: 10.0
# epsilon: 0.3930471999858451
# buffer size: 300000
# EPISODE 518
# reward: 175.0
# Clipped reward: 10.0
# epsilon: 0.39138759998584854
# buffer size: 300000
# EPISODE 519
# reward: 230.0
# Clipped reward: 14.0
# epsilon: 0.3892887999858529
# buffer size: 300000
# EPISODE 520
# reward: 355.0
# Clipped reward: 8.0
# epsilon: 0.3877209999858562
# buffer size: 300000
# EPISODE 521
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.38624859998585925
# buffer size: 300000
# EPISODE 522
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.38495439998586195
# buffer size: 300000
# EPISODE 523
# reward: 270.0
# Clipped reward: 13.0
# epsilon: 0.38317239998586566
# buffer size: 300000
# EPISODE 524
# reward: 105.0
# Clipped reward: 6.0
# epsilon: 0.3820149999858681
# buffer size: 300000
# EPISODE 525
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.3808053999858706
# buffer size: 300000
# EPISODE 526
# reward: 125.0
# Clipped reward: 6.0
# epsilon: 0.37934739998587363
# buffer size: 300000
# EPISODE 527
# reward: 85.0
# Clipped reward: 3.0
# epsilon: 0.37861479998587516
# buffer size: 300000
# EPISODE 528
# reward: 80.0
# Clipped reward: 2.0
# epsilon: 0.37795779998587653
# buffer size: 300000
# EPISODE 529
# reward: 185.0
# Clipped reward: 8.0
# epsilon: 0.3764817999858796
# buffer size: 300000
# EPISODE 530
# reward: 125.0
# Clipped reward: 6.0
# epsilon: 0.375344199985882
# buffer size: 300000
# EPISODE 531
# reward: 320.0
# Clipped reward: 6.0
# epsilon: 0.3739491999858849
# buffer size: 300000
# EPISODE 532
# reward: 305.0
# Clipped reward: 17.0
# epsilon: 0.3716271999858897
# buffer size: 300000
# EPISODE 533
# reward: 610.0
# Clipped reward: 11.0
# epsilon: 0.36892359998589536
# buffer size: 300000
# EPISODE 534
# reward: 150.0
# Clipped reward: 7.0
# epsilon: 0.36754299998589823
# buffer size: 300000
# EPISODE 535
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.36638019998590066
# buffer size: 300000
# EPISODE 536
# reward: 250.0
# Clipped reward: 12.0
# epsilon: 0.3646899999859042
# buffer size: 300000
# EPISODE 537
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.36330399998590707
# buffer size: 300000
# EPISODE 538
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.3617937999859102
# buffer size: 300000
# EPISODE 539
# reward: 355.0
# Clipped reward: 8.0
# epsilon: 0.3603663999859132
# buffer size: 300000
# EPISODE 540
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.3591531999859157
# buffer size: 300000
# EPISODE 541
# reward: 75.0
# Clipped reward: 2.0
# epsilon: 0.3584313999859172
# buffer size: 300000
# EPISODE 542
# reward: 475.0
# Clipped reward: 16.0
# epsilon: 0.356609799985921
# buffer size: 300000
# EPISODE 543
# reward: 260.0
# Clipped reward: 13.0
# epsilon: 0.35487639998592463
# buffer size: 300000
# EPISODE 544
# reward: 140.0
# Clipped reward: 7.0
# epsilon: 0.3532995999859279
# buffer size: 300000
# EPISODE 545
# reward: 125.0
# Clipped reward: 6.0
# epsilon: 0.3521115999859304
# buffer size: 300000
# EPISODE 546
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.35096859998593277
# buffer size: 300000
# EPISODE 547
# reward: 165.0
# Clipped reward: 7.0
# epsilon: 0.34954119998593575
# buffer size: 300000
# EPISODE 548
# reward: 550.0
# Clipped reward: 21.0
# epsilon: 0.3475557999859399
# buffer size: 300000
# EPISODE 549
# reward: 240.0
# Clipped reward: 12.0
# epsilon: 0.34542099998594433
# buffer size: 300000
# EPISODE 550
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.3439611999859474
# buffer size: 300000
# EPISODE 551
# reward: 460.0
# Clipped reward: 14.0
# epsilon: 0.3420279999859514
# buffer size: 300000
# EPISODE 552
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.34056639998595445
# buffer size: 300000
# EPISODE 553
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.339342399985957
# buffer size: 300000
# EPISODE 554
# reward: 515.0
# Clipped reward: 16.0
# epsilon: 0.33662079998596267
# buffer size: 300000
# EPISODE 555
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.33519339998596565
# buffer size: 300000
# EPISODE 556
# reward: 65.0
# Clipped reward: 3.0
# epsilon: 0.3340251999859681
# buffer size: 300000
# EPISODE 557
# reward: 135.0
# Clipped reward: 7.0
# epsilon: 0.3327795999859707
# buffer size: 300000
# EPISODE 558
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.33164559998597304
# buffer size: 300000
# EPISODE 559
# reward: 165.0
# Clipped reward: 7.0
# epsilon: 0.33014979998597616
# buffer size: 300000
# EPISODE 560
# reward: 470.0
# Clipped reward: 14.0
# epsilon: 0.3283911999859798
# buffer size: 300000
# EPISODE 561
# reward: 240.0
# Clipped reward: 12.0
# epsilon: 0.3268197999859831
# buffer size: 300000
# EPISODE 562
# reward: 320.0
# Clipped reward: 6.0
# epsilon: 0.3256191999859856
# buffer size: 300000
# EPISODE 563
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.324477999985988
# buffer size: 300000
# EPISODE 564
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.3237363999859895
# buffer size: 300000
# EPISODE 565
# reward: 210.0
# Clipped reward: 11.0
# epsilon: 0.3219795999859932
# buffer size: 300000
# EPISODE 566
# reward: 190.0
# Clipped reward: 13.0
# epsilon: 0.3202425999859968
# buffer size: 300000
# EPISODE 567
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.31911039998599916
# buffer size: 300000
# EPISODE 568
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.31761999998600227
# buffer size: 300000
# EPISODE 569
# reward: 165.0
# Clipped reward: 7.0
# epsilon: 0.31619259998600524
# buffer size: 300000
# EPISODE 570
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.3149703999860078
# buffer size: 300000
# EPISODE 571
# reward: 115.0
# Clipped reward: 4.0
# epsilon: 0.31379859998601023
# buffer size: 300000
# EPISODE 572
# reward: 90.0
# Clipped reward: 3.0
# epsilon: 0.31282839998601225
# buffer size: 300000
# EPISODE 573
# reward: 380.0
# Clipped reward: 10.0
# epsilon: 0.31110939998601583
# buffer size: 300000
# EPISODE 574
# reward: 90.0
# Clipped reward: 4.0
# epsilon: 0.31038219998601735
# buffer size: 300000
# EPISODE 575
# reward: 385.0
# Clipped reward: 10.0
# epsilon: 0.30884859998602054
# buffer size: 300000
# EPISODE 576
# reward: 275.0
# Clipped reward: 14.0
# epsilon: 0.3070053999860244
# buffer size: 300000
# EPISODE 577
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.3055545999860274
# buffer size: 300000
# EPISODE 578
# reward: 50.0
# Clipped reward: 1.0
# epsilon: 0.3048489999860289
# buffer size: 300000
# EPISODE 579
# reward: 315.0
# Clipped reward: 15.0
# epsilon: 0.30251439998603374
# buffer size: 300000
# EPISODE 580
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.3011067999860367
# buffer size: 300000
# EPISODE 581
# reward: 75.0
# Clipped reward: 2.0
# epsilon: 0.3004299999860381
# buffer size: 300000
# EPISODE 582
# reward: 240.0
# Clipped reward: 13.0
# epsilon: 0.2985075999860421
# buffer size: 300000
# EPISODE 583
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.29732499998604456
# buffer size: 300000
# EPISODE 584
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.29618379998604694
# buffer size: 300000
# EPISODE 585
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.2950083999860494
# buffer size: 300000
# EPISODE 586
# reward: 215.0
# Clipped reward: 10.0
# epsilon: 0.29344959998605263
# buffer size: 300000
# EPISODE 587
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.2922759999860551
# buffer size: 300000
# EPISODE 588
# reward: 300.0
# Clipped reward: 16.0
# epsilon: 0.29047419998605883
# buffer size: 300000
# EPISODE 589
# reward: 415.0
# Clipped reward: 11.0
# epsilon: 0.28888659998606214
# buffer size: 300000
# EPISODE 590
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.2876967999860646
# buffer size: 300000
# EPISODE 591
# reward: 55.0
# Clipped reward: 2.0
# epsilon: 0.28701459998606604
# buffer size: 300000
# EPISODE 592
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.2855043999860692
# buffer size: 300000
# EPISODE 593
# reward: 80.0
# Clipped reward: 3.0
# epsilon: 0.2844873999860713
# buffer size: 300000
# EPISODE 594
# reward: 365.0
# Clipped reward: 20.0
# epsilon: 0.2825595999860753
# buffer size: 300000
# EPISODE 595
# reward: 80.0
# Clipped reward: 3.0
# epsilon: 0.28182879998607685
# buffer size: 300000
# EPISODE 596
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.28063899998607933
# buffer size: 300000
# EPISODE 597
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.2792547999860822
# buffer size: 300000
# EPISODE 598
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.2778687999860851
# buffer size: 300000
# EPISODE 599
# reward: 160.0
# Clipped reward: 8.0
# epsilon: 0.2762955999860884
# buffer size: 300000
# EPISODE 600
# reward: 365.0
# Clipped reward: 8.0
# epsilon: 0.2748951999860913
# buffer size: 300000
# video/openaigym.video.0.118.video000125.mp4
# <video alt="test" autoplay
#                         loop controls style="height: 400px;">
#                         <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     </video>
# The network is saved to google_drive/My Drive/Colab Notebooks/trained_model/model.h5
# Playing the game!
# EPSIODE 0
# episode reward: 485.0
# EPSIODE 1
# episode reward: 80.0
# EPSIODE 2
# episode reward: 415.0
# EPSIODE 3
# episode reward: 105.0
# EPSIODE 4
# episode reward: 535.0
# EPSIODE 5
# episode reward: 605.0
# EPSIODE 6
# episode reward: 265.0
# EPSIODE 7
# episode reward: 135.0
# EPSIODE 8
# episode reward: 90.0
# EPSIODE 9
# episode reward: 355.0
# EPSIODE 10
# episode reward: 320.0
# EPSIODE 11
# episode reward: 180.0
# EPSIODE 12
# episode reward: 410.0
# EPSIODE 13
# episode reward: 110.0
# EPSIODE 14
# episode reward: 270.0
# EPSIODE 15
# episode reward: 135.0
# EPSIODE 16
# episode reward: 230.0
# EPSIODE 17
# episode reward: 210.0
# EPSIODE 18
# episode reward: 110.0
# EPSIODE 19
# episode reward: 120.0
# EPSIODE 20
# episode reward: 140.0
# EPSIODE 21
# episode reward: 155.0
# EPSIODE 22
# episode reward: 260.0
# EPSIODE 23
# episode reward: 270.0
# EPSIODE 24
# episode reward: 240.0
# EPSIODE 25
# episode reward: 110.0
# EPSIODE 26
# episode reward: 410.0
# EPSIODE 27
# episode reward: 140.0
# EPSIODE 28
# episode reward: 265.0
# EPSIODE 29
# episode reward: 180.0
# Loss is saved to google_drive/My Drive/Colab Notebooks/loss.txt
# Q values are saved to google_drive/My Drive/Colab Notebooks/Qvalues.txt
# Rewards are saved to google_drive/My Drive/Colab Notebooks/rewards.txt
# Replay buffer is saved to google_drive/My Drive/Colab Notebooks/replayBuffer.txt
# Epsilon is saved to google_drive/My Drive/Colab Notebooks/epsilon.txt
# Eval rewards are saved to google_drive/My Drive/Colab Notebooks/evalRewards.txt
# Eval Q values are saved to google_drive/My Drive/Colab Notebooks/evalQvalues.txt
# EPISODE 601
# reward: 80.0
# Clipped reward: 3.0
# epsilon: 0.2736981999860938
# buffer size: 300000
# EPISODE 602
# reward: 260.0
# Clipped reward: 13.0
# epsilon: 0.27195039998609744
# buffer size: 300000
# EPISODE 603
# reward: 315.0
# Clipped reward: 15.0
# epsilon: 0.2696769999861022
# buffer size: 300000
# EPISODE 604
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.2681883999861053
# buffer size: 300000
# EPISODE 605
# reward: 290.0
# Clipped reward: 16.0
# epsilon: 0.26628939998610923
# buffer size: 300000
# EPISODE 606
# reward: 185.0
# Clipped reward: 9.0
# epsilon: 0.2646801999861126
# buffer size: 300000
# EPISODE 607
# reward: 325.0
# Clipped reward: 17.0
# epsilon: 0.2623131999861175
# buffer size: 300000
# EPISODE 608
# reward: 425.0
# Clipped reward: 22.0
# epsilon: 0.25969779998612297
# buffer size: 300000
# EPISODE 609
# reward: 50.0
# Clipped reward: 1.0
# epsilon: 0.2589525999861245
# buffer size: 300000
# EPISODE 610
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.257773599986127
# buffer size: 300000
# EPISODE 611
# reward: 295.0
# Clipped reward: 15.0
# epsilon: 0.25586019998613097
# buffer size: 300000
# EPISODE 612
# reward: 380.0
# Clipped reward: 21.0
# epsilon: 0.25328079998613634
# buffer size: 300000
# EPISODE 613
# reward: 380.0
# Clipped reward: 9.0
# epsilon: 0.25183359998613936
# buffer size: 300000
# EPISODE 614
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.2511369999861408
# buffer size: 300000
# EPISODE 615
# reward: 225.0
# Clipped reward: 11.0
# epsilon: 0.24972039998614376
# buffer size: 300000
# EPISODE 616
# reward: 295.0
# Clipped reward: 16.0
# epsilon: 0.24796359998614742
# buffer size: 300000
# EPISODE 617
# reward: 235.0
# Clipped reward: 13.0
# epsilon: 0.24607719998615135
# buffer size: 300000
# EPISODE 618
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.24508719998615341
# buffer size: 300000
# EPISODE 619
# reward: 275.0
# Clipped reward: 14.0
# epsilon: 0.24329799998615714
# buffer size: 300000
# EPISODE 620
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.24212979998615958
# buffer size: 300000
# EPISODE 621
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.24094359998616205
# buffer size: 300000
# EPISODE 622
# reward: 65.0
# Clipped reward: 3.0
# epsilon: 0.24025779998616348
# buffer size: 300000
# EPISODE 623
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.239521599986165
# buffer size: 300000
# EPISODE 624
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.23806179998616805
# buffer size: 300000
# EPISODE 625
# reward: 80.0
# Clipped reward: 3.0
# epsilon: 0.2373669999861695
# buffer size: 300000
# EPISODE 626
# reward: 485.0
# Clipped reward: 15.0
# epsilon: 0.235683999986173
# buffer size: 300000
# EPISODE 627
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.23417379998617616
# buffer size: 300000
# EPISODE 628
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.23304159998617852
# buffer size: 300000
# EPISODE 629
# reward: 210.0
# Clipped reward: 11.0
# epsilon: 0.23126319998618222
# buffer size: 300000
# EPISODE 630
# reward: 380.0
# Clipped reward: 9.0
# epsilon: 0.2297367999861854
# buffer size: 300000
# EPISODE 631
# reward: 465.0
# Clipped reward: 14.0
# epsilon: 0.2279151999861892
# buffer size: 300000
# EPISODE 632
# reward: 290.0
# Clipped reward: 16.0
# epsilon: 0.2258937999861934
# buffer size: 300000
# EPISODE 633
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.22495779998619536
# buffer size: 300000
# EPISODE 634
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.2236005999861982
# buffer size: 300000
# EPISODE 635
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.22213899998620124
# buffer size: 300000
# EPISODE 636
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.22096539998620368
# buffer size: 300000
# EPISODE 637
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.2194245999862069
# buffer size: 300000
# EPISODE 638
# reward: 150.0
# Clipped reward: 7.0
# epsilon: 0.2182203999862094
# buffer size: 300000
# EPISODE 639
# reward: 75.0
# Clipped reward: 3.0
# epsilon: 0.21733659998621124
# buffer size: 300000
# EPISODE 640
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.21609819998621382
# buffer size: 300000
# EPISODE 641
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.21464739998621685
# buffer size: 300000
# EPISODE 642
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.2134755999862193
# buffer size: 300000
# EPISODE 643
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.2119311999862225
# buffer size: 300000
# EPISODE 644
# reward: 610.0
# Clipped reward: 23.0
# epsilon: 0.20935539998622787
# buffer size: 300000
# EPISODE 645
# reward: 415.0
# Clipped reward: 11.0
# epsilon: 0.20778579998623115
# buffer size: 300000
# EPISODE 646
# reward: 20.0
# Clipped reward: 0.0
# epsilon: 0.20712699998623252
# buffer size: 300000
# EPISODE 647
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.20587419998623513
# buffer size: 300000
# EPISODE 648
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.20443239998623813
# buffer size: 300000
# EPISODE 649
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.20326599998624056
# buffer size: 300000
# EPISODE 650
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.202090599986243
# buffer size: 300000
# EPISODE 651
# reward: 220.0
# Clipped reward: 10.0
# epsilon: 0.20062899998624606
# buffer size: 300000
# EPISODE 652
# reward: 145.0
# Clipped reward: 7.0
# epsilon: 0.19943559998624855
# buffer size: 300000
# EPISODE 653
# reward: 215.0
# Clipped reward: 10.0
# epsilon: 0.19780839998625194
# buffer size: 300000
# EPISODE 654
# reward: 125.0
# Clipped reward: 6.0
# epsilon: 0.19658619998625448
# buffer size: 300000
# EPISODE 655
# reward: 55.0
# Clipped reward: 2.0
# epsilon: 0.19587519998625597
# buffer size: 300000
# EPISODE 656
# reward: 135.0
# Clipped reward: 9.0
# epsilon: 0.19473939998625833
# buffer size: 300000
# EPISODE 657
# reward: 225.0
# Clipped reward: 11.0
# epsilon: 0.19318959998626156
# buffer size: 300000
# EPISODE 658
# reward: 380.0
# Clipped reward: 9.0
# epsilon: 0.191540799986265
# buffer size: 300000
# EPISODE 659
# reward: 275.0
# Clipped reward: 15.0
# epsilon: 0.18973179998626877
# buffer size: 300000
# EPISODE 660
# reward: 305.0
# Clipped reward: 16.0
# epsilon: 0.18777699998627284
# buffer size: 300000
# EPISODE 661
# reward: 95.0
# Clipped reward: 4.0
# epsilon: 0.18706779998627432
# buffer size: 300000
# EPISODE 662
# reward: 215.0
# Clipped reward: 10.0
# epsilon: 0.18550179998627758
# buffer size: 300000
# EPISODE 663
# reward: 135.0
# Clipped reward: 7.0
# epsilon: 0.18395019998628082
# buffer size: 300000
# EPISODE 664
# reward: 465.0
# Clipped reward: 14.0
# epsilon: 0.18221859998628442
# buffer size: 300000
# EPISODE 665
# reward: 185.0
# Clipped reward: 9.0
# epsilon: 0.1806471999862877
# buffer size: 300000
# EPISODE 666
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.17915139998629082
# buffer size: 300000
# EPISODE 667
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.17773299998629377
# buffer size: 300000
# EPISODE 668
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.17629839998629676
# buffer size: 300000
# EPISODE 669
# reward: 365.0
# Clipped reward: 19.0
# epsilon: 0.17376579998630204
# buffer size: 300000
# EPISODE 670
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.17255079998630457
# buffer size: 300000
# EPISODE 671
# reward: 160.0
# Clipped reward: 7.0
# epsilon: 0.17112159998630755
# buffer size: 300000
# EPISODE 672
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.16964379998631063
# buffer size: 300000
# EPISODE 673
# reward: 160.0
# Clipped reward: 8.0
# epsilon: 0.1681659999863137
# buffer size: 300000
# EPISODE 674
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.16675479998631665
# buffer size: 300000
# EPISODE 675
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.16554159998631918
# buffer size: 300000
# EPISODE 676
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.16407819998632223
# buffer size: 300000
# EPISODE 677
# reward: 55.0
# Clipped reward: 2.0
# epsilon: 0.16320159998632405
# buffer size: 300000
# EPISODE 678
# reward: 345.0
# Clipped reward: 7.0
# epsilon: 0.16175799998632706
# buffer size: 300000
# EPISODE 679
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.16029099998633012
# buffer size: 300000
# EPISODE 680
# reward: 445.0
# Clipped reward: 14.0
# epsilon: 0.1585287999863338
# buffer size: 300000
# EPISODE 681
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.15707439998633682
# buffer size: 300000
# EPISODE 682
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.15560379998633989
# buffer size: 300000
# EPISODE 683
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.15445539998634228
# buffer size: 300000
# EPISODE 684
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.15297219998634537
# buffer size: 300000
# EPISODE 685
# reward: 530.0
# Clipped reward: 18.0
# epsilon: 0.15095619998634957
# buffer size: 300000
# EPISODE 686
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.1495017999863526
# buffer size: 300000
# EPISODE 687
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.14797359998635579
# buffer size: 300000
# EPISODE 688
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.14654619998635876
# buffer size: 300000
# EPISODE 689
# reward: 260.0
# Clipped reward: 13.0
# epsilon: 0.14471199998636258
# buffer size: 300000
# EPISODE 690
# reward: 75.0
# Clipped reward: 2.0
# epsilon: 0.14401539998636403
# buffer size: 300000
# EPISODE 691
# reward: 290.0
# Clipped reward: 17.0
# epsilon: 0.14198679998636826
# buffer size: 300000
# EPISODE 692
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.1405323999863713
# buffer size: 300000
# EPISODE 693
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.13904919998637438
# buffer size: 300000
# EPISODE 694
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.13746879998637768
# buffer size: 300000
# Target_network is updated!
# Target_network is updated!
# Target_network is updated!
# Target_network is updated!
# EPISODE 695
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.13590279998638094
# buffer size: 300000
# EPISODE 696
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.13431879998638424
# buffer size: 300000
# EPISODE 697
# reward: 455.0
# Clipped reward: 14.0
# epsilon: 0.13258719998638785
# buffer size: 300000
# EPISODE 698
# reward: 225.0
# Clipped reward: 14.0
# epsilon: 0.1308771999863914
# buffer size: 300000
# EPISODE 699
# reward: 35.0
# Clipped reward: 2.0
# epsilon: 0.1300239999863932
# buffer size: 300000
# EPISODE 700
# reward: 145.0
# Clipped reward: 8.0
# epsilon: 0.12889899998639553
# buffer size: 300000
# video/openaigym.video.0.118.video000216.mp4
# <video alt="test" autoplay
#                         loop controls style="height: 400px;">
#                         <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     </video>
# The network is saved to google_drive/My Drive/Colab Notebooks/trained_model/model.h5
# Playing the game!
# EPSIODE 0
# episode reward: 210.0
# EPSIODE 1
# episode reward: 10.0
# EPSIODE 2
# episode reward: 80.0
# EPSIODE 3
# episode reward: 390.0
# EPSIODE 4
# episode reward: 345.0
# EPSIODE 5
# episode reward: 140.0
# EPSIODE 6
# episode reward: 545.0
# EPSIODE 7
# episode reward: 115.0
# EPSIODE 8
# episode reward: 120.0
# EPSIODE 9
# episode reward: 285.0
# EPSIODE 10
# episode reward: 440.0
# EPSIODE 11
# episode reward: 220.0
# EPSIODE 12
# episode reward: 370.0
# EPSIODE 13
# episode reward: 175.0
# EPSIODE 14
# episode reward: 240.0
# EPSIODE 15
# episode reward: 120.0
# EPSIODE 16
# episode reward: 45.0
# EPSIODE 17
# episode reward: 150.0
# EPSIODE 18
# episode reward: 115.0
# EPSIODE 19
# episode reward: 410.0
# EPSIODE 20
# episode reward: 150.0
# EPSIODE 21
# episode reward: 205.0
# EPSIODE 22
# episode reward: 115.0
# EPSIODE 23
# episode reward: 65.0
# EPSIODE 24
# episode reward: 460.0
# EPSIODE 25
# episode reward: 70.0
# EPSIODE 26
# episode reward: 180.0
# EPSIODE 27
# episode reward: 115.0
# EPSIODE 28
# episode reward: 125.0
# EPSIODE 29
# episode reward: 105.0
# Loss is saved to google_drive/My Drive/Colab Notebooks/loss.txt
# Q values are saved to google_drive/My Drive/Colab Notebooks/Qvalues.txt
# Rewards are saved to google_drive/My Drive/Colab Notebooks/rewards.txt
# Replay buffer is saved to google_drive/My Drive/Colab Notebooks/replayBuffer.txt
# Epsilon is saved to google_drive/My Drive/Colab Notebooks/epsilon.txt
# Eval rewards are saved to google_drive/My Drive/Colab Notebooks/evalRewards.txt
# Eval Q values are saved to google_drive/My Drive/Colab Notebooks/evalQvalues.txt
# EPISODE 701
# reward: 170.0
# Clipped reward: 9.0
# epsilon: 0.12765519998639813
# buffer size: 300000
# EPISODE 702
# reward: 80.0
# Clipped reward: 3.0
# epsilon: 0.1264635999864006
# buffer size: 300000
# EPISODE 703
# reward: 145.0
# Clipped reward: 6.0
# epsilon: 0.12520359998640324
# buffer size: 300000
# EPISODE 704
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.12399219998640576
# buffer size: 300000
# EPISODE 705
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.1230633999864077
# buffer size: 300000
# EPISODE 706
# reward: 240.0
# Clipped reward: 12.0
# epsilon: 0.12135519998641126
# buffer size: 300000
# EPISODE 707
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.11995119998641418
# buffer size: 300000
# EPISODE 708
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.11841759998641738
# buffer size: 300000
# EPISODE 709
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.11684079998642066
# buffer size: 300000
# EPISODE 710
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.11560779998642323
# buffer size: 300000
# EPISODE 711
# reward: 415.0
# Clipped reward: 11.0
# epsilon: 0.11405079998642648
# buffer size: 300000
# EPISODE 712
# reward: 290.0
# Clipped reward: 14.0
# epsilon: 0.11231559998643009
# buffer size: 300000
# EPISODE 713
# reward: 85.0
# Clipped reward: 3.0
# epsilon: 0.11118699998643244
# buffer size: 300000
# EPISODE 714
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.10968759998643557
# buffer size: 300000
# EPISODE 715
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.10824579998643857
# buffer size: 300000
# EPISODE 716
# reward: 215.0
# Clipped reward: 10.0
# epsilon: 0.10668519998644183
# buffer size: 300000
# EPISODE 717
# reward: 505.0
# Clipped reward: 17.0
# epsilon: 0.10484919998644565
# buffer size: 300000
# EPISODE 718
# reward: 270.0
# Clipped reward: 17.0
# epsilon: 0.10288179998644975
# buffer size: 300000
# EPISODE 719
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.10139319998645285
# buffer size: 300000
# EPISODE 720
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 721
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 722
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 723
# reward: 400.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 724
# reward: 485.0
# Clipped reward: 15.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 725
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 726
# reward: 465.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 727
# reward: 450.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 728
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 729
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 730
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 731
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 732
# reward: 80.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 733
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 734
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 735
# reward: 125.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 736
# reward: 175.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 737
# reward: 95.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 738
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 739
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 740
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 741
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 742
# reward: 185.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 743
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 744
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 745
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 746
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 747
# reward: 345.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 748
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 749
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 750
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 751
# reward: 235.0
# Clipped reward: 12.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 752
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 753
# reward: 290.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 754
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 755
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 756
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 757
# reward: 75.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 758
# reward: 35.0
# Clipped reward: 1.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 759
# reward: 65.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 760
# reward: 35.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 761
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 762
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 763
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 764
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 765
# reward: 75.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 766
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 767
# reward: 140.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 768
# reward: 135.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 769
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 770
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 771
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 772
# reward: 265.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 773
# reward: 680.0
# Clipped reward: 27.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 774
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 775
# reward: 350.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 776
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 777
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 778
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 779
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 780
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 781
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 782
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 783
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 784
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 785
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 786
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 787
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 788
# reward: 320.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 789
# reward: 80.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 790
# reward: 140.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 791
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 792
# reward: 140.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 793
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 794
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 795
# reward: 185.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 796
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 797
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 798
# reward: 380.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 799
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 800
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# video/openaigym.video.0.118.video000343.mp4
# <video alt="test" autoplay
#                         loop controls style="height: 400px;">
#                         <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     </video>
# The network is saved to google_drive/My Drive/Colab Notebooks/trained_model/model.h5
# Playing the game!
# EPSIODE 0
# episode reward: 135.0
# EPSIODE 1
# episode reward: 105.0
# EPSIODE 2
# episode reward: 410.0
# EPSIODE 3
# episode reward: 210.0
# EPSIODE 4
# episode reward: 240.0
# EPSIODE 5
# episode reward: 105.0
# EPSIODE 6
# episode reward: 110.0
# EPSIODE 7
# episode reward: 185.0
# EPSIODE 8
# episode reward: 180.0
# EPSIODE 9
# episode reward: 105.0
# EPSIODE 10
# episode reward: 210.0
# EPSIODE 11
# episode reward: 135.0
# EPSIODE 12
# episode reward: 180.0
# EPSIODE 13
# episode reward: 75.0
# EPSIODE 14
# episode reward: 455.0
# EPSIODE 15
# episode reward: 210.0
# EPSIODE 16
# episode reward: 135.0
# EPSIODE 17
# episode reward: 120.0
# EPSIODE 18
# episode reward: 110.0
# EPSIODE 19
# episode reward: 355.0
# EPSIODE 20
# episode reward: 110.0
# EPSIODE 21
# episode reward: 135.0
# EPSIODE 22
# episode reward: 210.0
# EPSIODE 23
# episode reward: 155.0
# EPSIODE 24
# episode reward: 180.0
# EPSIODE 25
# episode reward: 160.0
# EPSIODE 26
# episode reward: 210.0
# EPSIODE 27
# episode reward: 110.0
# EPSIODE 28
# episode reward: 110.0
# EPSIODE 29
# episode reward: 180.0
# Loss is saved to google_drive/My Drive/Colab Notebooks/loss.txt
# Q values are saved to google_drive/My Drive/Colab Notebooks/Qvalues.txt
# Rewards are saved to google_drive/My Drive/Colab Notebooks/rewards.txt
# Replay buffer is saved to google_drive/My Drive/Colab Notebooks/replayBuffer.txt
# Epsilon is saved to google_drive/My Drive/Colab Notebooks/epsilon.txt
# Eval rewards are saved to google_drive/My Drive/Colab Notebooks/evalRewards.txt
# Eval Q values are saved to google_drive/My Drive/Colab Notebooks/evalQvalues.txt
# EPISODE 801
# reward: 80.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 802
# reward: 270.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 803
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 804
# reward: 510.0
# Clipped reward: 17.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 805
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 806
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 807
# reward: 440.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 808
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 809
# reward: 285.0
# Clipped reward: 15.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 810
# reward: 185.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 811
# reward: 365.0
# Clipped reward: 19.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 812
# reward: 280.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 813
# reward: 440.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 814
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 815
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 816
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 817
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 818
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 819
# reward: 185.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 820
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 821
# reward: 420.0
# Clipped reward: 12.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 822
# reward: 65.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 823
# reward: 255.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 824
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 825
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 826
# reward: 215.0
# Clipped reward: 12.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 827
# reward: 130.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 828
# reward: 465.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 829
# reward: 90.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 830
# reward: 305.0
# Clipped reward: 18.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 831
# reward: 150.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 832
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 833
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 834
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 835
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 836
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 837
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 838
# reward: 120.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 839
# reward: 380.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 840
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 841
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 842
# reward: 335.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 843
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 844
# reward: 65.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 845
# reward: 150.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 846
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 847
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 848
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 849
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 850
# reward: 460.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 851
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 852
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 853
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 854
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 855
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 856
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 857
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 858
# reward: 260.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 859
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 860
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 861
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 862
# reward: 185.0
# Clipped reward: 11.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 863
# reward: 185.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 864
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 865
# reward: 75.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 866
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 867
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 868
# reward: 225.0
# Clipped reward: 11.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 869
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 870
# reward: 380.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 871
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 872
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 873
# reward: 170.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 874
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 875
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 876
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 877
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 878
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 879
# reward: 415.0
# Clipped reward: 11.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 880
# reward: 355.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 881
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 882
# reward: 310.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 883
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 884
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 885
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 886
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 887
# reward: 80.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 888
# reward: 210.0
# Clipped reward: 11.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 889
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 890
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 891
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 892
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 893
# reward: 275.0
# Clipped reward: 17.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 894
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 895
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 896
# reward: 50.0
# Clipped reward: 1.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 897
# reward: 185.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 898
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 899
# reward: 310.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 900
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# video/openaigym.video.0.118.video000512.mp4
# <video alt="test" autoplay
#                         loop controls style="height: 400px;">
#                         <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     </video>
# The network is saved to google_drive/My Drive/Colab Notebooks/trained_model/model.h5
# Playing the game!
# EPSIODE 0
# episode reward: 210.0
# EPSIODE 1
# episode reward: 30.0
# EPSIODE 2
# episode reward: 30.0
# EPSIODE 3
# episode reward: 180.0
# EPSIODE 4
# episode reward: 50.0
# EPSIODE 5
# episode reward: 175.0
# EPSIODE 6
# episode reward: 80.0
# EPSIODE 7
# episode reward: 210.0
# EPSIODE 8
# episode reward: 165.0
# EPSIODE 9
# episode reward: 210.0
# EPSIODE 10
# episode reward: 110.0
# EPSIODE 11
# episode reward: 180.0
# EPSIODE 12
# episode reward: 240.0
# EPSIODE 13
# episode reward: 260.0
# EPSIODE 14
# episode reward: 105.0
# EPSIODE 15
# episode reward: 410.0
# EPSIODE 16
# episode reward: 355.0
# EPSIODE 17
# episode reward: 575.0
# EPSIODE 18
# episode reward: 110.0
# EPSIODE 19
# episode reward: 80.0
# EPSIODE 20
# episode reward: 445.0
# EPSIODE 21
# episode reward: 210.0
# EPSIODE 22
# episode reward: 610.0
# EPSIODE 23
# episode reward: 500.0
# EPSIODE 24
# episode reward: 155.0
# EPSIODE 25
# episode reward: 110.0
# EPSIODE 26
# episode reward: 110.0
# EPSIODE 27
# episode reward: 215.0
# EPSIODE 28
# episode reward: 180.0
# EPSIODE 29
# episode reward: 210.0
# Loss is saved to google_drive/My Drive/Colab Notebooks/loss.txt
# Q values are saved to google_drive/My Drive/Colab Notebooks/Qvalues.txt
# Rewards are saved to google_drive/My Drive/Colab Notebooks/rewards.txt
# Replay buffer is saved to google_drive/My Drive/Colab Notebooks/replayBuffer.txt
# Epsilon is saved to google_drive/My Drive/Colab Notebooks/epsilon.txt
# Eval rewards are saved to google_drive/My Drive/Colab Notebooks/evalRewards.txt
# Eval Q values are saved to google_drive/My Drive/Colab Notebooks/evalQvalues.txt
# EPISODE 901
# ...
# EPSIODE 5
# episode reward: 155.0
# EPSIODE 6
# episode reward: 180.0
# EPSIODE 7
# episode reward: 180.0
# EPSIODE 8
# episode reward: 380.0
# EPSIODE 9
# episode reward: 110.0
# EPSIODE 10
# episode reward: 210.0
# EPSIODE 11
# episode reward: 180.0
# EPSIODE 12
# episode reward: 290.0
# EPSIODE 13
# episode reward: 185.0
# EPSIODE 14
# episode reward: 260.0
# EPSIODE 15
# episode reward: 210.0
# EPSIODE 16
# episode reward: 210.0
# EPSIODE 17
# episode reward: 110.0
# EPSIODE 18
# episode reward: 410.0
# EPSIODE 19
# episode reward: 180.0
# EPSIODE 20
# episode reward: 55.0
# EPSIODE 21
# episode reward: 295.0
# EPSIODE 22
# episode reward: 240.0
# EPSIODE 23
# episode reward: 110.0
# EPSIODE 24
# episode reward: 80.0
# EPSIODE 25
# episode reward: 50.0
# EPSIODE 26
# episode reward: 260.0
# EPSIODE 27
# episode reward: 180.0
# EPSIODE 28
# episode reward: 215.0
# EPSIODE 29
# episode reward: 180.0
# Loss is saved to google_drive/My Drive/Colab Notebooks/loss.txt
# Q values are saved to google_drive/My Drive/Colab Notebooks/Qvalues.txt
# Rewards are saved to google_drive/My Drive/Colab Notebooks/rewards.txt
# Replay buffer is saved to google_drive/My Drive/Colab Notebooks/replayBuffer.txt
# Epsilon is saved to google_drive/My Drive/Colab Notebooks/epsilon.txt
# Eval rewards are saved to google_drive/My Drive/Colab Notebooks/evalRewards.txt
# Eval Q values are saved to google_drive/My Drive/Colab Notebooks/evalQvalues.txt
# EPISODE 1001
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1002
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1003
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1004
# reward: 75.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1005
# reward: 55.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1006
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1007
# reward: 140.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1008
# reward: 240.0
# Clipped reward: 12.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1009
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1010
# reward: 355.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1011
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1012
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1013
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1014
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1015
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1016
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1017
# reward: 30.0
# Clipped reward: 0.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1018
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1019
# reward: 460.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1020
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1021
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1022
# reward: 120.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1023
# reward: 125.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1024
# reward: 350.0
# Clipped reward: 19.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1025
# reward: 80.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1026
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1027
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1028
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1029
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1030
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1031
# reward: 460.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1032
# reward: 240.0
# Clipped reward: 12.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1033
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1034
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1035
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1036
# reward: 120.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1037
# reward: 380.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1038
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1039
# reward: 265.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1040
# reward: 280.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1041
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1042
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1043
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1044
# reward: 260.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1045
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1046
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1047
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1048
# reward: 35.0
# Clipped reward: 1.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1049
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1050
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1051
# reward: 515.0
# Clipped reward: 18.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1052
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1053
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1054
# reward: 240.0
# Clipped reward: 12.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1055
# reward: 215.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1056
# reward: 475.0
# Clipped reward: 25.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1057
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1058
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1059
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1060
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1061
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1062
# reward: 565.0
# Clipped reward: 20.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1063
# reward: 185.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1064
# reward: 220.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1065
# reward: 485.0
# Clipped reward: 15.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1066
# reward: 50.0
# Clipped reward: 1.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1067
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1068
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1069
# reward: 280.0
# Clipped reward: 15.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1070
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1071
# reward: 355.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1072
# reward: 445.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1073
# reward: 285.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1074
# reward: 55.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1075
# reward: 55.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1076
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1077
# reward: 285.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1078
# reward: 205.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1079
# reward: 210.0
# Clipped reward: 11.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1080
# reward: 260.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1081
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1082
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1083
# reward: 25.0
# Clipped reward: -1.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1084
# reward: 135.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1085
# reward: 410.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1086
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1087
# reward: 285.0
# Clipped reward: 14.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1088
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1089
# reward: 465.0
# Clipped reward: 17.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1090
# reward: 185.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1091
# reward: 180.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1092
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1093
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1094
# reward: 105.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1095
# reward: 185.0
# Clipped reward: 8.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1096
# reward: 50.0
# Clipped reward: 1.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1097
# reward: 80.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1098
# reward: 270.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1099
# reward: 20.0
# Clipped reward: 0.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1100
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# video/openaigym.video.0.118.video000729.mp4
# <video alt="test" autoplay
#                         loop controls style="height: 400px;">
#                         <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     </video>
# The network is saved to google_drive/My Drive/Colab Notebooks/trained_model/model.h5
# Playing the game!
# EPSIODE 0
# episode reward: 440.0
# EPSIODE 1
# episode reward: 35.0
# EPSIODE 2
# episode reward: 210.0
# EPSIODE 3
# episode reward: 250.0
# EPSIODE 4
# episode reward: 270.0
# EPSIODE 5
# episode reward: 215.0
# EPSIODE 6
# episode reward: 70.0
# EPSIODE 7
# episode reward: 125.0
# EPSIODE 8
# episode reward: 30.0
# EPSIODE 9
# episode reward: 210.0
# EPSIODE 10
# episode reward: 105.0
# EPSIODE 11
# episode reward: 155.0
# EPSIODE 12
# episode reward: 45.0
# EPSIODE 13
# episode reward: 210.0
# EPSIODE 14
# episode reward: 210.0
# EPSIODE 15
# episode reward: 80.0
# EPSIODE 16
# episode reward: 120.0
# EPSIODE 17
# episode reward: 380.0
# EPSIODE 18
# episode reward: 290.0
# EPSIODE 19
# episode reward: 410.0
# EPSIODE 20
# episode reward: 55.0
# EPSIODE 21
# episode reward: 460.0
# EPSIODE 22
# episode reward: 215.0
# EPSIODE 23
# episode reward: 125.0
# EPSIODE 24
# episode reward: 180.0
# EPSIODE 25
# episode reward: 210.0
# EPSIODE 26
# episode reward: 155.0
# EPSIODE 27
# episode reward: 260.0
# EPSIODE 28
# episode reward: 135.0
# EPSIODE 29
# episode reward: 110.0
# Loss is saved to google_drive/My Drive/Colab Notebooks/loss.txt
# Q values are saved to google_drive/My Drive/Colab Notebooks/Qvalues.txt
# Rewards are saved to google_drive/My Drive/Colab Notebooks/rewards.txt
# Replay buffer is saved to google_drive/My Drive/Colab Notebooks/replayBuffer.txt
# Epsilon is saved to google_drive/My Drive/Colab Notebooks/epsilon.txt
# Eval rewards are saved to google_drive/My Drive/Colab Notebooks/evalRewards.txt
# Eval Q values are saved to google_drive/My Drive/Colab Notebooks/evalQvalues.txt
# EPISODE 1101
# reward: 295.0
# Clipped reward: 17.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1102
# reward: 75.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1103
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1104
# reward: 80.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# Target_network is updated!
# Target_network is updated!
# Target_network is updated!
# Target_network is updated!
# EPISODE 1105
# reward: 185.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1106
# reward: 260.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1107
# reward: 115.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1108
# reward: 120.0
# Clipped reward: 5.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1109
# reward: 20.0
# Clipped reward: 0.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1110
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1111
# reward: 120.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1112
# reward: 50.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1113
# reward: 260.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1114
# reward: 155.0
# Clipped reward: 7.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1115
# reward: 380.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1116
# reward: 380.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1117
# reward: 260.0
# Clipped reward: 13.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1118
# reward: 295.0
# Clipped reward: 17.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1119
# reward: 55.0
# Clipped reward: 2.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1120
# reward: 215.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1121
# reward: 65.0
# Clipped reward: 3.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1122
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1123
# reward: 215.0
# Clipped reward: 10.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1124
# reward: 70.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1125
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1126
# reward: 125.0
# Clipped reward: 6.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1127
# reward: 80.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1128
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1129
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1130
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1131
# reward: 110.0
# Clipped reward: 4.0
# epsilon: 0.09999999998645576
# buffer size: 300000
# EPISODE 1132
# reward: 210.0
# Clipped reward: 9.0
# epsilon: 0.09999999998645576
# buffer size: 300000

# %% [markdown]
# # **Play the game**

# %%
epsilon = 0
episodes = 3
space_invaders = Environment('SpaceInvaders-v0',ACTIONS)
space_invaders.wrap_env()
Q = DQN(RESOLUTION, NUM_OF_FRAMES, len(ACTIONS), OPTIMIZER)

agent = Agent()
e_rewards, q_values, mean_reward, mean_q_value = agent.play_game(epsilon, Q, space_invaders, episodes, load_pretrained=True, render=True)
space_invaders.show_video()
print("Average episode reward is {}".format(mean_reward))
# Out:
# Playing the game!
# The network is loaded from google_drive/My Drive/Colab Notebooks/trained_model/model.h5
# EPSIODE 0
# episode reward: 275.0
# EPSIODE 1
# episode reward: 265.0
# EPSIODE 2
# episode reward: 290.0
# video/openaigym.video.3.6673.video000001.mp4
# <video alt="test" autoplay
#                         loop controls style="height: 400px;">
#                         <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     </video>
# Average episode reward is 276.6666666666667

# %% [markdown]
# # DEBUG

# %%
# CHECK the packState and unpackState (what goes in and out of replay buffer)

space_invaders = Environment('SpaceInvaders-v0',ACTIONS)
space_invaders.wrap_env()
d = True
for i in range(1000):
    if d:
       frames,_,_ = space_invaders.resetEnv(NUM_OF_FRAMES)
       frames_buffer=frames
    o, r,d, info = space_invaders.step(np.random.randint(0,6))
    if i == 500:
        state = stackFrames(frames_buffer)
    frame = preprocessFrame(o,RESOLUTION)
    frames_buffer.append(frame)
    frames_buffer.pop(0)
packed_state = packState(state)
unpacked_state = unpackState(packed_state,RESOLUTION, NUM_OF_FRAMES)
for i in range(NUM_OF_FRAMES):
    plt.figure()
    plt.imshow(state[:,:,i])
    plt.figure()
    plt.imshow(unpacked_state[:,:,i])

# %%
# Check target_network and network
